# %%
import numpy as np
import pandas as pd

# %%
#Data Analysis............
twitter_train = pd.read_csv('twitter_train.csv')

# %%
twitter_test = pd.read_csv('twitter_test.csv')

# %%
twitter_train.shape
# Out:
# (10980, 12)

# %%
twitter_test.shape
# Out:
# (3660, 11)

# %%
twitter_train.head()
# Out:
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
# 2  568089179520954368          positive     United                    NaN
# 3  568928195581513728          negative  Southwest                    NaN
# 4  568594180014014464          negative     United                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
# 2      LocalKyle                 NaN              0
# 3    amccarthy19                 NaN              0
# 4        J_Okayy                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
# 2  @united Flew ORD to Miami and back and  had gr...         NaN
# 3     @SouthwestAir @dultch97 that's horse radish 😤🐴         NaN
# 4  @united so our flight into ORD was delayed bec...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2  2015-02-18 08:46:29 -0800                    Illinois
# 3  2015-02-20 16:20:26 -0800                         NaN
# 4  2015-02-19 18:13:11 -0800                         NaN
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)
# 2  Central Time (US & Canada)
# 3      Atlantic Time (Canada)
# 4  Eastern Time (US & Canada)

# %%
twitter_test.head()
# Out:
#              tweet_id     airline airline_sentiment_gold          name  \
# 0  569682010270101504    American                    NaN      zsalim03
# 1  569608307184242688    American                    NaN      sa_craig
# 2  567879304593408001   Southwest                    NaN  DanaChristos
# 3  569757651539660801  US Airways                    NaN      rossj987
# 4  569900705852608513    American                    NaN    tranpham18
#
#   negativereason_gold  retweet_count  \
# 0                 NaN              0
# 1                 NaN              0
# 2                 NaN              1
# 3                 NaN              0
# 4                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...         NaN
# 1  @AmericanAir after all, the plane didn’t land ...         NaN
# 2  @SouthwestAir can't believe how many paying cu...         NaN
# 3  @USAirways I can legitimately say that I would...         NaN
# 4  @AmericanAir still no response from AA. great ...         NaN
#
#                tweet_created       tweet_location               user_timezone
# 0  2015-02-22 18:15:50 -0800                Texas  Central Time (US & Canada)
# 1  2015-02-22 13:22:57 -0800  College Station, TX  Central Time (US & Canada)
# 2  2015-02-17 18:52:31 -0800                   CT  Eastern Time (US & Canada)
# 3  2015-02-22 23:16:24 -0800     Washington, D.C.  Eastern Time (US & Canada)
# 4  2015-02-23 08:44:51 -0800        New York City  Eastern Time (US & Canada)

# %%
twitter_train.isnull().sum()
# Out:
# tweet_id                      0
# airline_sentiment             0
# airline                       0
# airline_sentiment_gold    10949
# name                          0
# negativereason_gold       10956
# retweet_count                 0
# text                          0
# tweet_coord               10204
# tweet_created                 0
# tweet_location             3550
# user_timezone              3577
# dtype: int64

# %%
twitter_train.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline', 'airline_sentiment_gold',
#        'name', 'negativereason_gold', 'retweet_count', 'text', 'tweet_coord',
#        'tweet_created', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
set(twitter_train['retweet_count'].values)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8, 15, 18, 22, 28, 31, 44}

# %%
set(twitter_train['airline_sentiment'].values)
# Out:
# {'negative', 'neutral', 'positive'}

# %%
set(twitter_train['airline'].values)
# Out:
# {'American', 'Delta', 'Southwest', 'US Airways', 'United', 'Virgin America'}

# %%
ex = []
ex.append([(twitter_train.loc[2,'text'], 'negative')])
ex.append([(twitter_train.loc[2,'text'], 'negative')])
ex[0]
len(ex)
# Out:
# 2

# %%
##Fetching Text and Sentiments for applying NLP
def Fetch_Text_sent(data):
    tweet_text = []
    row = twitter_train.shape[0]
    for i in range(row):
        tweet_text.append((twitter_train.loc[i,'text'] , twitter_train.loc[i,'airline_sentiment']))
    return tweet_text

# %%
##Checking function Fetch_Text_sent()
sample = twitter_train.iloc[0:5,0:]
xtrain = Fetch_Text_sent(sample)
len(xtrain)
# Out:
# 10980

# %%
nlp_xtrain=[('','')]
nlp_xtrain = Fetch_Text_sent(twitter_train.iloc[0:,0:])
nlp_xtrain[0]
# Out:
# ('@SouthwestAir I am scheduled for the morning, 2 days after the fact, yes..not sure why my evening flight was the only one Cancelled Flightled',
#  'negative')

# %%
nlp_xtest=[('','')]
nlp_xtest = Fetch_Text_sent(twitter_test.iloc[0:,0:])
len(nlp_xtest)
# Out:
# 10980

# %%
from nltk import WordNetLemmatizer as WL
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize as WT
from nltk import pos_tag

# %%
xtrain_word = []
for text in nlp_xtrain:
    xtrain_word.append([WT(text[0]) , text[1]])

# %%
xtest_word = []
for text in nlp_xtest:
    xtest_word.append([WT(text[0]) , text[1]])

# %%
xtest_word[0]
# Out:
# [['@',
#   'SouthwestAir',
#   'I',
#   'am',
#   'scheduled',
#   'for',
#   'the',
#   'morning',
#   ',',
#   '2',
#   'days',
#   'after',
#   'the',
#   'fact',
#   ',',
#   'yes..not',
#   'sure',
#   'why',
#   'my',
#   'evening',
#   'flight',
#   'was',
#   'the',
#   'only',
#   'one',
#   'Cancelled',
#   'Flightled'],
#  'negative']

# %%
import string
from nltk.corpus import stopwords
stop = stopwords.words('english')
punc = list(string.punctuation)
stop = stop+punc

# %%
def get_simple_tag(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
def clean_reviews(word):
    output_words = []
    for w in word:
        if w.lower() not in stop:
            pos = pos_tag([w])
            lemm = WL()
            lem_word = lemm.lemmatize(w,pos = get_simple_tag(pos[0][1]))
            output_words.append(lem_word.lower())
    return output_words

# %%
clean_data = []
for doc in xtrain_word:
    clean_data.append((clean_reviews(doc[0]),doc[1]))
clean_data[0:5]
# Out:
# [(['southwestair',
#    'schedule',
#    'morning',
#    '2',
#    'day',
#    'fact',
#    'yes..not',
#    'sure',
#    'even',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'),
#  (['southwestair',
#    'see',
#    'worker',
#    'time',
#    'time',
#    'go',
#    'beyond',
#    'love',
#    'fly',
#    'guy',
#    'thank'],
#   'positive'),
#  (['united',
#    'flew',
#    'ord',
#    'miami',
#    'back',
#    'great',
#    'crew',
#    'service',
#    'leg',
#    'thanks'],
#   'positive'),
#  (['southwestair', 'dultch97', "'s", 'horse', 'radish', '😤🐴'], 'negative'),
#  (['united',
#    'flight',
#    'ord',
#    'delayed',
#    'air',
#    'force',
#    'one',
#    'last',
#    'flight',
#    'sbn',
#    '8:20',
#    '5',
#    'min',
#    'land'],
#   'negative')]

# %%
len(clean_data)
# Out:
# 10980

# %%
cleanTest_data = []
for doc in xtrain_word:
    cleanTest_data.append((clean_reviews(doc[0]),doc[1]))
cleanTest_data[0:5]
# Out:
# [(['southwestair',
#    'schedule',
#    'morning',
#    '2',
#    'day',
#    'fact',
#    'yes..not',
#    'sure',
#    'even',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'),
#  (['southwestair',
#    'see',
#    'worker',
#    'time',
#    'time',
#    'go',
#    'beyond',
#    'love',
#    'fly',
#    'guy',
#    'thank'],
#   'positive'),
#  (['united',
#    'flew',
#    'ord',
#    'miami',
#    'back',
#    'great',
#    'crew',
#    'service',
#    'leg',
#    'thanks'],
#   'positive'),
#  (['southwestair', 'dultch97', "'s", 'horse', 'radish', '😤🐴'], 'negative'),
#  (['united',
#    'flight',
#    'ord',
#    'delayed',
#    'air',
#    'force',
#    'one',
#    'last',
#    'flight',
#    'sbn',
#    '8:20',
#    '5',
#    'min',
#    'land'],
#   'negative')]

# %%
from sklearn.feature_extraction.text import CountVectorizer
categories = [categ for doc,categ in clean_data]

# %%
len(categories)
# Out:
# 10980

# %%
text_docs =  [" ".join(doc) for doc,categ in clean_data]

# %%
test_text_docs = [" ".join(doc) for doc,categ in cleanTest_data]

# %%
text_docs[0]
# Out:
# 'southwestair schedule morning 2 day fact yes..not sure even flight one cancelled flightled'

# %%
count_vec = CountVectorizer(stop_words = stop,max_features=3000)

# %%
x_train = count_vec.fit_transform(text_docs)

# %%
x_train.shape
# Out:
# (10980, 3000)

# %%
x_test = count_vec.transform(test_text_docs)
count_vec.get_feature_names()
# Out:
# ['00',
#  '000',
#  '00pm',
#  '02',
#  '03',
#  '05',
#  '10',
#  '100',
#  '1000',
#  '10a',
#  '10am',
#  '10hrs',
#  '10pm',
#  '11',
#  '11am',
#  '11th',
#  '12',
#  '1230',
#  '13',
#  '130',
#  '1359',
#  '136',
#  '14',
#  '140',
#  '15',
#  '150',
#  '152',
#  '1583',
#  '15th',
#  '16',
#  '17',
#  '18',
#  '180',
#  '1800',
#  '1898',
#  '19',
#  '1hr',
#  '1k',
#  '1pm',
#  '1st',
#  '20',
#  '200',
#  '2000',
#  '2014',
#  '2015',
#  '20min',
#  '21',
#  '21st',
#  '22',
#  '23',
#  '24',
#  '24h',
#  '24hrs',
#  '24th',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '28th',
#  '29',
#  '2b',
#  '2d',
#  '2day',
#  '2days',
#  '2hr',
#  '2hrs',
#  '2nd',
#  '2pm',
#  '2x',
#  '30',
#  '300',
#  '3056',
#  '30a',
#  '30am',
#  '30k',
#  '30min',
#  '30pm',
#  '31',
#  '3130',
#  '32',
#  '35',
#  '350',
#  '36',
#  '386',
#  '39',
#  '3am',
#  '3d',
#  '3fq3xelbon',
#  '3hrs',
#  '3pm',
#  '3rd',
#  '3x',
#  '40',
#  '400',
#  '40pm',
#  '413',
#  '42',
#  '4322',
#  '433',
#  '44',
#  '45',
#  '4567',
#  '45min',
#  '47',
#  '48',
#  '4pm',
#  '4th',
#  '4x',
#  '50',
#  '500',
#  '50am',
#  '50k',
#  '50pm',
#  '51',
#  '55',
#  '58',
#  '59',
#  '5hrs',
#  '5th',
#  '60',
#  '600',
#  '65',
#  '699',
#  '6am',
#  '6pm',
#  '70',
#  '700',
#  '719',
#  '728',
#  '7300',
#  '737',
#  '747',
#  '75',
#  '777',
#  '787',
#  '7am',
#  '7th',
#  '80',
#  '800',
#  '80th',
#  '85832',
#  '8am',
#  '8aug',
#  '8pm',
#  '8wbzorrn3c',
#  '90',
#  '919',
#  '99',
#  '9am',
#  '9pm',
#  'a1',
#  'a320',
#  'aa',
#  'aa2444',
#  'aadvantage',
#  'abandon',
#  'abc',
#  'ability',
#  'able',
#  'aboard',
#  'abq',
#  'absolute',
#  'absolutely',
#  'absurd',
#  'abt',
#  'abuse',
#  'abysmal',
#  'ac',
#  'accept',
#  'acceptable',
#  'accepted',
#  'access',
#  'accident',
#  'accidentally',
#  'accommodate',
#  'accommodation',
#  'accomplish',
#  'accord',
#  'accordingly',
#  'account',
#  'accountability',
#  'acct',
#  'accurate',
#  'acknowledge',
#  'across',
#  'act',
#  'action',
#  'actual',
#  'actually',
#  'ad',
#  'add',
#  'additional',
#  'address',
#  'adds',
#  'addtl',
#  'admiral',
#  'admirals',
#  'admit',
#  'advance',
#  'advantage',
#  'advertise',
#  'advice',
#  'advise',
#  'advisory',
#  'affect',
#  'affected',
#  'afford',
#  'affordable',
#  'afternoon',
#  'age',
#  'agency',
#  'agent',
#  'agents',
#  'aggressive',
#  'ago',
#  'agree',
#  'ah',
#  'ahead',
#  'ahold',
#  'air',
#  'airbus',
#  'aircanada',
#  'aircraft',
#  'airfare',
#  'airline',
#  'airlinegeeks',
#  'airlines',
#  'airplane',
#  'airport',
#  'airway',
#  'airways',
#  'aisle',
#  'alaska',
#  'albany',
#  'alert',
#  'ali',
#  'alive',
#  'allergy',
#  'alliance',
#  'allow',
#  'allowance',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'alternate',
#  'alternative',
#  'although',
#  'altitude',
#  'always',
#  'amateur',
#  'amaze',
#  'amazing',
#  'america',
#  'american',
#  'americanair',
#  'americanairlines',
#  'americanview',
#  'amex',
#  'among',
#  'amount',
#  'amp',
#  'amybruni',
#  'ana',
#  'andrews',
#  'angel',
#  'angry',
#  'anniversary',
#  'announce',
#  'announcement',
#  'announces',
#  'annoy',
#  'annoyed',
#  'annricord',
#  'another',
#  'answer',
#  'anthony',
#  'anticipate',
#  'antonio',
#  'anxious',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'apart',
#  'apologize',
#  'apologizes',
#  'apology',
#  'app',
#  'appalled',
#  'apparently',
#  'appear',
#  'appease',
#  'apple',
#  'application',
#  'apply',
#  'appointment',
#  'appreciate',
#  'appreciates',
#  'approach',
#  'appropriate',
#  'approve',
#  'approx',
#  'apps',
#  'april',
#  'apt',
#  'aqjn4hwnac',
#  'area',
#  'argue',
#  'argument',
#  'arizona',
#  'around',
#  'arrange',
#  'arrangement',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'article',
#  'aruba',
#  'asap',
#  'ase',
#  'ashamed',
#  'ask',
#  'asked',
#  'askpaypal',
#  'asks',
#  'asleep',
#  'aspen',
#  'assault',
#  'asset',
#  'asshole',
#  'assign',
#  'assignment',
#  'assist',
#  'assistance',
#  'assult',
#  'assume',
#  'assure',
#  'atc',
#  'athlete',
#  'atl',
#  'atlanta',
#  'atlantic',
#  'atrocious',
#  'attach',
#  'attempt',
#  'attend',
#  'attendant',
#  'attention',
#  'attitude',
#  'aug',
#  'august',
#  'auh',
#  'aus',
#  'austin',
#  'austinairport',
#  'australia',
#  'auto',
#  'automate',
#  'automatically',
#  'avail',
#  'availability',
#  'available',
#  'average',
#  'avgeek',
#  'aviation',
#  'aviv',
#  'avoid',
#  'await',
#  'award',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'awkward',
#  'aww',
#  'awww',
#  'b1',
#  'b16',
#  'b4',
#  'b6',
#  'b737',
#  'b767',
#  'b787',
#  'ba',
#  'baby',
#  'back',
#  'backlog',
#  'backup',
#  'bad',
#  'badcustomerservice',
#  'badge',
#  'badly',
#  'badservice',
#  'bae',
#  'bag',
#  'baggage',
#  'bags',
#  'bahamas',
#  'balance',
#  'ball',
#  'baltimore',
#  'band',
#  'bank',
#  'bankrupt',
#  'bar',
#  'barbados',
#  'barely',
#  'base',
#  'basic',
#  'basically',
#  'bathroom',
#  'battery',
#  'batting',
#  'battle',
#  'bay',
#  'bc',
#  'bday',
#  'bdl',
#  'beach',
#  'beat',
#  'beautiful',
#  'beauty',
#  'become',
#  'bed',
#  'beer',
#  'begin',
#  'behavior',
#  'behind',
#  'believe',
#  'belize',
#  'belonging',
#  'belt',
#  'benefit',
#  'bereavement',
#  'besides',
#  'best',
#  'bet',
#  'better',
#  'beverage',
#  'beware',
#  'beyond',
#  'bf',
#  'bhm',
#  'big',
#  'bike',
#  'bill',
#  'bin',
#  'bird',
#  'birmingham',
#  'birthday',
#  'bit',
#  'bitch',
#  'biz',
#  'black',
#  'blah',
#  'blame',
#  'block',
#  'blog',
#  'bloody',
#  'blue',
#  'bluemanity',
#  'bna',
#  'board',
#  'boarding',
#  'boat',
#  'bonus',
#  'boo',
#  'book',
#  'booked',
#  'booking',
#  'boot',
#  'bos',
#  'boston',
#  'bostonlogan',
#  'bot',
#  'bother',
#  'bottle',
#  'bought',
#  'bounce',
#  'bound',
#  'box',
#  'boy',
#  'boyfriend',
#  'brain',
#  'brand',
#  'brandmance',
#  'break',
#  'breakfast',
#  'bridge',
#  'brilliant',
#  'bring',
#  'broke',
#  'broken',
#  'brother',
#  'brought',
#  'browser',
#  'brutal',
#  'bs',
#  'btw',
#  'buf',
#  'buffalo',
#  'bug',
#  'bullshit',
#  'bummer',
#  'bump',
#  'bumped',
#  'bumping',
#  'bunch',
#  'bus',
#  'bush',
#  'business',
#  'busy',
#  'button',
#  'buy',
#  'buying',
#  'bwi',
#  'c26',
#  'ca',
#  'cab',
#  'cabin',
#  'cabo',
#  'cake',
#  'cali',
#  'california',
#  'call',
#  'callback',
#  'called',
#  'caller',
#  'calling',
#  'camera',
#  'canada',
#  'canadian',
#  'cancelled',
#  'cancun',
#  'cant',
#  'captain',
#  'car',
#  'card',
#  'care',
#  'carousel',
#  'carrier',
#  'carrieunderwood',
#  'carry',
#  'carryon',
#  'carseat',
#  'cart',
#  'case',
#  'cash',
#  'catch',
#  'cater',
#  'catering',
#  'cause',
#  'cc',
#  'celebrate',
#  'cell',
#  'center',
#  'central',
#  'century',
#  'ceo',
#  'certain',
#  'certainly',
#  'certificate',
#  'cessna',
#  'chair',
#  'chairman',
#  'challenge',
#  'chance',
#  'change',
#  'channel',
#  'chaos',
#  'character',
#  'charge',
#  'charity',
#  'charleston',
#  'charlotte',
#  'chase',
#  'chat',
#  'cheap',
#  'cheaper',
#  'cheapflights',
#  'check',
#  'checked',
#  'checkin',
#  'checkout',
#  'cheer',
#  'cheers',
#  'cheese',
#  'cherry',
#  'chi',
#  'chicago',
#  'chicken',
#  'child',
#  'china',
#  'chocolate',
#  'choice',
#  'choose',
#  'chose',
#  'chrome',
#  'circle',
#  'circumstance',
#  'city',
#  'claim',
#  'claimed',
#  'clarification',
#  'clarify',
#  'class',
#  'cle',
#  'clean',
#  'clear',
#  'clearly',
#  'cleveland',
#  'click',
#  'client',
#  'close',
#  'closer',
#  'closest',
#  'clothes',
#  'clothing',
#  'cloud',
#  'clt',
#  'club',
#  'clue',
#  'cluster',
#  'cmh',
#  'cmon',
#  'cnn',
#  'co',
#  'coach',
#  'coast',
#  'coat',
#  'cocktail',
#  'code',
#  'coffee',
#  'coincidence',
#  'cold',
#  'colleague',
#  'college',
#  'color',
#  'columbia',
#  'columbus',
#  'com',
#  'combination',
#  'combine',
#  'come',
#  'comfort',
#  'comfortable',
#  'comm',
#  'comment',
#  'commercial',
#  'commit',
#  'commitment',
#  'common',
#  'communicate',
#  'communication',
#  'comp',
#  'companion',
#  'company',
#  'compare',
#  'compassion',
#  'compensate',
#  'compensation',
#  'competitor',
#  'complain',
#  'complaint',
#  'complete',
#  'completely',
#  'complicate',
#  'compliment',
#  'complimentary',
#  'computer',
#  'con',
#  'concept',
#  'concern',
#  'concerned',
#  'concourse',
#  'condition',
#  'conf',
#  'conference',
#  'confident',
#  'confirm',
#  'confirmation',
#  'conflict',
#  'confuse',
#  'confusion',
#  'congrats',
#  'connect',
#  'connection',
#  'connector',
#  'consecutive',
#  'consider',
#  'consideration',
#  'considering',
#  'consistent',
#  'consistently',
#  'constant',
#  'constantly',
#  'cont',
#  'contact',
#  'content',
#  'contest',
#  'continental',
#  'contingency',
#  'continually',
#  'continue',
#  'continued',
#  'continuous',
#  'contract',
#  'control',
#  'convenient',
#  'conversation',
#  'cool',
#  'coordinate',
#  'copy',
#  'corp',
#  'corporate',
#  'corporation',
#  'correct',
#  'correctly',
#  'cost',
#  'costa',
#  'costumer',
#  'cot',
#  'could',
#  'couldnt',
#  'count',
#  'counter',
#  'counting',
#  'country',
#  'couple',
#  'coupon',
#  'course',
#  'courteous',
#  'courtesy',
#  'cousin',
#  'cover',
#  'cowboycerrone',
#  'coworker',
#  'cr',
#  'cracker',
#  'cranky',
#  'crap',
#  'crappy',
#  'crash',
#  'crashed',
#  'crazy',
#  'create',
#  'credit',
#  'crew',
#  'crewmember',
#  'crisis',
#  'cross',
#  'crowd',
#  'cruise',
#  'cry',
#  'cs',
#  'csr',
#  'ct',
#  'ctl',
#  'cuba',
#  'cue',
#  'cun',
#  'cup',
#  'curious',
#  'current',
#  'currently',
#  'cushion',
#  'cust',
#  'custom',
#  'customer',
#  'customers',
#  'customerservice',
#  'customerservicefail',
#  'custserv',
#  'cut',
#  'cute',
#  'cuz',
#  'cvg',
#  'cx',
#  'cxl',
#  'cxld',
#  'dad',
#  'daily',
#  'dal',
#  'dallas',
#  'dallaslovefield',
#  'damage',
#  'damn',
#  'dance',
#  'dang',
#  'dare',
#  'dark',
#  'darn',
#  'data',
#  'date',
#  'daughter',
#  'david',
#  'day',
#  'days',
#  'daytona',
#  'dc',
#  'dca',
#  'de',
#  'dead',
#  'deadhead',
#  'deaf',
#  'deal',
#  'dealt',
#  'dear',
#  'death',
#  'debacle',
#  'december',
#  'decent',
#  'decide',
#  'decision',
#  'decisions',
#  'deck',
#  'deep',
#  'def',
#  'define',
#  'definitely',
#  'definition',
#  'degree',
#  'deice',
#  'delay',
#  'delayed',
#  'delays',
#  'delete',
#  'deliver',
#  'delivery',
#  'delta',
#  'deltaassist',
#  'den',
#  'denver',
#  'deny',
#  'dep',
#  'depart',
#  'department',
#  'departs',
#  'departure',
#  'deplane',
#  'deplaned',
#  'deplorable',
#  'dept',
#  'derrick',
#  'describe',
#  'deserve',
#  'deserves',
#  'design',
#  'desk',
#  'desktop',
#  'desperately',
#  'despite',
#  'dest',
#  'destination',
#  'destinationdragons',
#  'destroyed',
#  'detail',
#  'device',
#  'dfw',
#  'dfwairport',
#  'dia',
#  'dial',
#  'didnt',
#  'die',
#  'diego',
#  'diff',
#  'difference',
#  'different',
#  'difficult',
#  'digital',
#  'dinner',
#  'direct',
#  'directly',
#  'directtv',
#  'dirty',
#  'disappear',
#  'disappoint',
#  'disappointed',
#  'disappointing',
#  'disappointment',
#  'disaster',
#  'disconnect',
#  'discount',
#  'discover',
#  'discus',
#  'disgrace',
#  'disgraceful',
#  'disgust',
#  'dislike',
#  'disney',
#  'disorganize',
#  'dispute',
#  'disregard',
#  'disrespect',
#  'dissatisfied',
#  'distance',
#  'div',
#  'diversion',
#  'divert',
#  'dividend',
#  'dl',
#  'dm',
#  'dmed',
#  'dming',
#  'dms',
#  'document',
#  'doesnt',
#  'dog',
#  'dollar',
#  'domestic',
#  'donate',
#  'done',
#  'dont',
#  'door',
#  'dot',
#  'double',
#  'doubt',
#  'downgrade',
#  'download',
#  'downtown',
#  'dozen',
#  'dpt',
#  'dr',
#  'dragon',
#  'dragons',
#  'draw',
#  'dream',
#  'drink',
#  'drive',
#  'driven',
#  'driver',
#  'drop',
#  'drove',
#  'drunk',
#  'dsm',
#  'dtw',
#  'dublin',
#  'dude',
#  'due',
#  'dulles',
#  'dulles_airport',
#  'dumb',
#  'dunno',
#  'duty',
#  'e190',
#  'eagle',
#  'earlier',
#  'early',
#  'earn',
#  'earth',
#  'easily',
#  'east',
#  'eastern',
#  'easy',
#  'eat',
#  'econ',
#  'economy',
#  'ed',
#  'efficient',
#  'effort',
#  'either',
#  'el',
#  'elevate',
#  'elite',
#  'ellahenderson',
#  'else',
#  'elsewhere',
#  'em',
#  'email',
#  'embarrass',
#  'emboss',
#  'emergency',
#  'empathy',
#  'employee',
#  'empty',
#  'encounter',
#  'end',
#  'enforce',
#  'engine',
#  'english',
#  'enjoy',
#  'enough',
#  'enroute',
#  'ensure',
#  'enter',
#  'entertain',
#  'entertainment',
#  'entire',
#  'entirely',
#  'ep',
#  'epic',
#  ...]

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
svmclf = svm.SVC()
svmclf.fit(x_train,categories)
# Out:
# /home/hackme/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
svmpred = svmclf.predict(x_test)
set(svmpred)
# Out:
# {'negative'}

# %%
import csv


with open('output.csv', 'w') as csvFile:
    writer = csv.writer(csvFile,delimiter=",")
    for r in svmpred:
      writer.writerow([r])
